# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Working with Pearl Global industries ltd(PGIL) data

# %%
pgil = pd.read_excel('pgil.xlsx')
pgil
# Out:
#     Year  Open Price  High Price  Low Price  Close Price  No.of Shares  \
# 0   2007      500.00      580.25     200.00       292.45      25349190
# 1   2008      294.00      363.90      43.25        66.55       5103126
# 2   2009       64.55      127.95      36.00        86.05       7330158
# 3   2010       86.90       99.70      56.35        62.45      10694083
# 4   2011       62.00       85.40      44.75        47.10       2435677
# 5   2012       47.00      130.25      46.95       120.15       1767714
# 6   2013      120.50      179.90      93.00       175.00       1813810
# 7   2014      177.00      239.90     115.80       224.00       1949229
# 8   2015      224.00      282.00     184.00       250.40       1287341
# 9   2016      241.00      257.70     127.00       136.00       1086564
# 10  2017      137.90      178.00     110.00       138.25       1356004
# 11  2018      141.00      167.00      95.00       139.85        809776
# ...

# %%
pgil.drop(['DematFlagExist'], axis=1, inplace=True)
pgil.rename(columns = {'Year':'year','Open Price':'open_price','High Price':'high_price','Low Price':'low_price','Close Price':'close_price','No.of Shares':'no_of_shares','No. of Trades':'no_of_trades','Total Turnover in Rs':'turnover_in_rs','Deliverable Quantity':'deliverable_quantity'}, inplace=True)
pgil.head(2)
# Out:
#    year  open_price  high_price  low_price  close_price  no_of_shares  \
# 0  2007       500.0      580.25     200.00       292.45      25349190
# 1  2008       294.0      363.90      43.25        66.55       5103126
#
#    no_of_trades  turnover_in_rs  deliverable_quantity  \
# 0        508825     10018564192               6086494
# 1         99535       988661161               2343061
#
#    % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                      24.01           380.25            -207.55
# 1                      45.91           320.65            -227.45

# %%
print(plt.style.available)
mpl.style.use(['ggplot'])
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
fig = plt.figure(figsize=(8,3))
x=pgil['year']
y=pgil['turnover_in_rs']
plt.title('Pearl global industries LTD turnover (in Rs.)')
plt.xlabel('Year')
plt.ylabel('Total turnovrt in Rs.')
plt.plot(x, y, alpha=1, color='#a800b1', linestyle='-', linewidth=0.5, marker='.', markeredgecolor='red', 
         markeredgewidth=1, markersize=10, markerfacecolor='yellow', visible=True)
plt.show()

# %%
fig = plt.figure(figsize=(8,3))
x=pgil['year']
y=pgil['close_price']
plt.title('Pearl global industries LTD share price details (in Rs)')
plt.xlabel('Year')
plt.ylabel('Share price')
plt.plot(x, y,label='Close price of shares',marker='.')
plt.plot(pgil['year'],pgil['open_price'],label='Open price of shares',marker='.')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8,3))
plt.plot(pgil['year'],pgil['no_of_trades'],label='Total number of trades',marker='.')
plt.plot(pgil['year'],pgil['no_of_shares'],label='Total number of shares',marker='.')
plt.plot(pgil['year'],pgil['deliverable_quantity'],label='Total deliverable quantity',marker='.')
plt.xlabel('Year')
plt.title('Pearl global industries ltd (Trades vs Shares vs Deliverable quantity)')
plt.legend()
plt.show()

# %% [markdown]
# # Working with world_population data

# %%
world_population = pd.read_excel('world_population.xls')
world_population.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965  ...         2011         2012         2013         2014  \
# ...

# %%
world_population.drop(columns = ['1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972',
                                 '1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984',
                                 '1985','1986','1987','1988','1989','1990'], axis=1, inplace=True)
world_population.set_index('Country Name', inplace=True)
world_population.index.name = None
world_population.head(2)
# Out:
#                             Country Code     Indicator Name Indicator Code  \
# Aruba                                ABW  Population, total    SP.POP.TOTL
# Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
#
#                                     1991         1992         1993  \
# Aruba                            64623.0      68240.0      72495.0
# Africa Eastern and Southern  313394693.0  322270073.0  331265579.0
#
#                                     1994         1995         1996  \
# Aruba                            76705.0      80324.0      83211.0
# Africa Eastern and Southern  340379934.0  349605660.0  358953595.0
#
#                                     1997  ...         2011         2012  \
# Aruba                            85450.0  ...     102050.0     102565.0
# Africa Eastern and Southern  368440591.0  ...  532760424.0  547482863.0
#
#                                     2013         2014         2015  \
# ...

# %%
years = list(map(str, range(1991, 2020)))

fig = plt.figure(figsize=(10,3))
world_population.loc['India', years].plot(kind = 'line')
plt.title('Population of India from 1991 to 2020')
plt.xlabel('Year')
plt.ylabel('Total population in billion')

plt.show()

# %%
#To check the population of India & China (style-1)
#It is not looking good

years = list(map(str, range(1991, 2020)))

fig = plt.figure(figsize=(10,3))
world_population.loc[['India','China'], years].plot(kind = 'line')
plt.title('Population of India & China from 1991 to 2020')
plt.xlabel('Year')
plt.ylabel('Total population in billion')

plt.show()

# %%
#To check the population of India & China (style-2)

years = list(map(str, range(1991, 2020)))

fig = plt.figure(figsize=(10,5))
world_population.loc['India', years].plot(kind = 'line', label = 'Population of India')
world_population.loc['China', years].plot(kind = 'line', label = 'Population of China')
plt.title('Population of India & China from 1991 to 2020')
plt.xlabel('Year')
plt.ylabel('Total population in billion')
plt.legend()
plt.show()

# %%
world_population.index
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=266)

# %%
world_population.drop(['European Union', 'Arab World','Europe & Central Asia (excluding high income)','Middle East & North Africa (excluding high income)','Middle East & North Africa (IDA & IBRD countries)', 'North America','Euro area', 'Africa Eastern and Southern', 'Afghanistan','Africa Western and Central', 'World', 'IDA & IBRD total', 'Low & middle income', 'Middle income','IBRD only', 'Early-demographic dividend', 'Lower middle income','Upper middle income', 'East Asia & Pacific','Late-demographic dividend','East Asia & Pacific (excluding high income)','East Asia & Pacific (IDA & IBRD countries)', 'South Asia (IDA & IBRD)','South Asia', 'IDA total', 'OECD members','High income', 'Sub-Saharan Africa (IDA & IBRD countries)','Sub-Saharan Africa','Sub-Saharan Africa (excluding high income)', 'IDA only','Post-demographic dividend','Least developed countries: UN classification','Pre-demographic dividend', 'Fragile and conflict affected situations','Europe & Central Asia',
'Heavily indebted poor countries (HIPC)','Low income', 'Latin America & Caribbean','Latin America & the Caribbean (IDA & IBRD countries)','Latin America & Caribbean (excluding high income)', 'IDA blend','Middle East & North Africa','Europe & Central Asia (IDA & IBRD countries)','European Union', 'Arab World','Europe & Central Asia (excluding high income)','Middle East & North Africa (excluding high income)','Middle East & North Africa (IDA & IBRD countries)', 'North America','Euro area'
], axis=0, inplace=True)

# %%
#Top five contries with high population

years = list(map(str, range(1991, 2020)))

inplace = True
world_population.sort_values(by='2020', ascending=False, axis=0, inplace=True)

df_top5 = world_population.head(5)
df_top5 = df_top5[years].transpose()

print(df_top5)

df_top5.index = df_top5.index.map(int)
df_top5.plot(kind='line', figsize=(14, 8))
plt.title('Top five countries in population')
plt.xlabel('Year')
plt.ylabel('Population in billion')
plt.show()
# Out:
#              China         India  United States    Indonesia     Pakistan
# 1991  1.150780e+09  8.912732e+08    252981000.0  184591897.0  110778655.0
# 1992  1.164970e+09  9.093070e+08    256514000.0  187739786.0  113911126.0
# 1993  1.178440e+09  9.274039e+08    259919000.0  190851184.0  117086680.0
# 1994  1.191835e+09  9.456018e+08    263126000.0  193917458.0  120362764.0
# 1995  1.204855e+09  9.639226e+08    266278000.0  196934257.0  123776835.0
# 1996  1.217550e+09  9.823652e+08    269394000.0  199901231.0  127349293.0
# 1997  1.230075e+09  1.000900e+09    272657000.0  202826444.0  131057432.0
# 1998  1.241935e+09  1.019484e+09    275854000.0  205724597.0  134843233.0
# 1999  1.252735e+09  1.038058e+09    279040000.0  208615171.0  138624625.0
# 2000  1.262645e+09  1.056576e+09    282162411.0  211513822.0  142343583.0
# 2001  1.271850e+09  1.075000e+09    284968955.0  214427419.0  145978408.0
# 2002  1.280400e+09  1.093317e+09    287625193.0  217357790.0  149549695.0
# ...
